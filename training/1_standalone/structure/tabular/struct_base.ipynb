# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix, matthews_corrcoef, accuracy_score, balanced_accuracy_score
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.preprocessing import RobustScaler
import matplotlib.pyplot as plt
import random
# Out:
# 2025-04-08 16:43:35.224000: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744130615.245443  981643 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744130615.251911  981643 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-08 16:43:35.274481: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Set random seeds for reproducibility
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
tf.keras.utils.set_random_seed(SEED)  # This sets all random seeds in keras
tf.config.experimental.enable_op_determinism()  # For complete reproducibility

# %%
def prepare_structure_data(df):
    """Structure data preparation without contacts"""
    features_list = []
    middle_pos = 16  
    
    # Normalize angles to their circular nature
    def normalize_angles(angle_array, pos):
        angles = np.array([arr[pos] for arr in angle_array])
        angle_rad = np.pi * angles / 180.0
        return np.stack([np.sin(angle_rad), np.cos(angle_rad)], axis=-1)
    
    # 1. Process angles
    angles = ['phi', 'psi', 'omega']
    for angle in angles:
        angle_arrays = np.array([np.array(eval(x)) for x in df[angle]])
        angle_features = normalize_angles(angle_arrays, middle_pos)
        features_list.append(angle_features)
        print(f"{angle} features shape: {angle_features.shape}")
    
    # 2. Process SASA
    sasa_arrays = np.array([np.array(eval(x)) for x in df['sasa']])
    scaler = RobustScaler()
    sasa_features = []
    for pos in [middle_pos-1, middle_pos, middle_pos+1]:
        sasa_pos = np.array([arr[pos] for arr in sasa_arrays]).reshape(-1, 1)
        sasa_scaled = scaler.fit_transform(sasa_pos)
        sasa_features.append(sasa_scaled)
    sasa_features = np.concatenate(sasa_features, axis=1)
    features_list.append(sasa_features)
    print(f"SASA features shape: {sasa_features.shape}")
    
    # 3. Process chi angles
    chi_angles = ['chi1', 'chi2', 'chi3', 'chi4']
    for chi in chi_angles:
        chi_arrays = np.array([np.array(eval(x)) for x in df[chi]])
        chi_features = normalize_angles(chi_arrays, middle_pos)
        features_list.append(chi_features)
        print(f"{chi} features shape: {chi_features.shape}")
    
    # 4. Process SS (optional)
    ss_arrays = np.array([list(seq) for seq in df['ss']])
    ss_center = ss_arrays[:, middle_pos]
    ss_encoded = np.zeros((len(ss_arrays), 3))
    ss_map = {'H': 0, 'E': 1, 'L': 2}
    for i, ss in enumerate(ss_center):
        ss_encoded[i, ss_map[ss]] = 1
    features_list.append(ss_encoded)
    print(f"SS features shape: {ss_encoded.shape}")
    
    # 5. Process plDDT
    plddt_arrays = np.array([np.array(eval(x)) for x in df['plDDT']])
    plddt_center = np.array([arr[middle_pos] for arr in plddt_arrays]).reshape(-1, 1)
    scaler = RobustScaler()
    plddt_scaled = scaler.fit_transform(plddt_center)
    features_list.append(plddt_scaled)
    print(f"plDDT features shape: {plddt_scaled.shape}")
    
    # Combine all features
    features = np.concatenate(features_list, axis=1)
    print(f"\nFinal combined features shape: {features.shape}")
    print("Feature list lengths:", [f.shape[1] for f in features_list])
    
    return features

# %%
def create_structure_model(input_dim):
    """Create a standalone model for structural features
    
    Args:
        input_dim: The dimensionality of the structural features
        
    Returns:
        A compiled Keras model
    """
    model = tf.keras.Sequential([
        tf.keras.layers.Input(shape=(input_dim,)),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(32, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    
    return model

# %%
def print_metrics(y_true, y_pred):
    """
    Print comprehensive evaluation metrics
    
    Parameters:
    y_true: array-like of true labels
    y_pred: array-like of predicted labels
    """
    # Calculate confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    
    # Calculate metrics
    acc = accuracy_score(y_true, y_pred)
    balanced_acc = balanced_accuracy_score(y_true, y_pred)
    mcc = matthews_corrcoef(y_true, y_pred)
    sensitivity = cm[1][1] / (cm[1][1] + cm[1][0])  # True Positive Rate
    specificity = cm[0][0] / (cm[0][0] + cm[0][1])  # True Negative Rate
    
    # Print results
    print(f"Accuracy: {acc:.4f}")
    print(f"Balanced Accuracy: {balanced_acc:.4f}")
    print(f"MCC: {mcc:.4f}")
    print(f"Sensitivity: {sensitivity:.4f}")
    print(f"Specificity: {specificity:.4f}")
    print("Confusion Matrix:")
    print(cm)

# %%
def train_and_evaluate_seq_only():
    """Train and evaluate structure-based model"""
    print("Loading structural data...")
    
    # Load data
    train_df = pd.read_csv("../../../../data/train/structure/processed_features_train.csv")
    test_df = pd.read_csv("../../../../data/test/structure/processed_features_test.csv")
    
    # Extract labels
    y_train = train_df['label'].values
    y_test = test_df['label'].values
    
    # Prepare feature data
    X_train = prepare_structure_data(train_df)
    X_test = prepare_structure_data(test_df)
    
    # Shuffle training data (important since negatives come first, then positives)
    shuffle_idx = np.random.RandomState(42).permutation(len(y_train))
    X_train = X_train[shuffle_idx]
    y_train = y_train[shuffle_idx]
    
    # Calculate class weights
    total_samples = len(y_train)
    pos_samples = np.sum(y_train == 1)
    neg_samples = np.sum(y_train == 0)
    
    class_weights = {
        0: total_samples / (2 * neg_samples),
        1: total_samples / (2 * pos_samples)
    }
    
    print(f"Training data shape: {X_train.shape}")
    print(f"Testing data shape: {X_test.shape}")
    print(f"Class weights: {class_weights}")
    
    # Cross-validation setup
    kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    metrics = {'acc': [], 'balanced_acc': [], 'mcc': [], 'sn': [], 'sp': []}
    test_predictions = []
    
    for fold, (train_idx, val_idx) in enumerate(kfold.split(X_train, y_train), 1):
        print(f"\nFold {fold}/5")
        
        # Callbacks
        callbacks = [
            tf.keras.callbacks.EarlyStopping(
                monitor='val_loss',
                patience=10,
                restore_best_weights=True
            ),
            tf.keras.callbacks.ReduceLROnPlateau(
                monitor='val_loss',
                factor=0.5,
                patience=5,
                min_lr=1e-6
            )
        ]
        
        # Create and compile model
        model = create_structure_model(X_train.shape[1])
        model.compile(
            optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
            loss='binary_crossentropy',
            metrics=['accuracy']
        )
        
        # Train model
        history = model.fit(
            X_train[train_idx], 
            y_train[train_idx],
            validation_data=(
                X_train[val_idx], 
                y_train[val_idx]
            ),
            batch_size=32,
            epochs=50,
            callbacks=callbacks,
            class_weight=class_weights,
            verbose=1
        )
        
        # Plot training history
        plt.figure(figsize=(10, 6))
        plt.plot(history.history['accuracy'], label='Train Accuracy')
        plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
        plt.title(f'Model Accuracy - Fold {fold}')
        plt.xlabel('Epoch')
        plt.ylabel('Accuracy')
        plt.legend()
        plt.show()
        
        # Evaluate on validation set
        val_pred = model.predict(X_train[val_idx])
        val_pred_binary = (val_pred > 0.5).astype(int)
        
        # Calculate metrics
        cm = confusion_matrix(y_train[val_idx], val_pred_binary)
        metrics['acc'].append(accuracy_score(y_train[val_idx], val_pred_binary))
        metrics['balanced_acc'].append(balanced_accuracy_score(y_train[val_idx], val_pred_binary))
        metrics['mcc'].append(matthews_corrcoef(y_train[val_idx], val_pred_binary))
        metrics['sn'].append(cm[1][1]/(cm[1][1]+cm[1][0]))
        metrics['sp'].append(cm[0][0]/(cm[0][0]+cm[0][1]))
        
        # Predict on test set
        test_pred = model.predict(X_test)
        test_predictions.append(test_pred)
        
        print(f"\nFold {fold} Results:")
        print(f"Accuracy: {metrics['acc'][-1]:.4f}")
        print(f"Balanced Accuracy: {metrics['balanced_acc'][-1]:.4f}")
        print(f"MCC: {metrics['mcc'][-1]:.4f}")
        print(f"Sensitivity: {metrics['sn'][-1]:.4f}")
        print(f"Specificity: {metrics['sp'][-1]:.4f}")
    
    # Print average cross-validation results
    print("\nAverage Cross-validation Results:")
    for metric in metrics:
        print(f"{metric.upper()}: {np.mean(metrics[metric]):.4f} ± {np.std(metrics[metric]):.4f}")
    
    # Ensemble predictions on test set
    test_pred_avg = np.mean(test_predictions, axis=0)
    test_pred_binary = (test_pred_avg > 0.5).astype(int)
    
    # Calculate final test metrics
    cm_test = confusion_matrix(y_test, test_pred_binary)
    
    print("\nFinal Test Set Results:")
    print(f"Accuracy: {accuracy_score(y_test, test_pred_binary):.4f}")
    print(f"Balanced Accuracy: {balanced_accuracy_score(y_test, test_pred_binary):.4f}")
    print(f"MCC: {matthews_corrcoef(y_test, test_pred_binary):.4f}")
    print(f"Sensitivity: {cm_test[1][1]/(cm_test[1][1]+cm_test[1][0]):.4f}")
    print(f"Specificity: {cm_test[0][0]/(cm_test[0][0]+cm_test[0][1]):.4f}")
    print("Confusion Matrix:")
    print(cm_test)
    
    return model, test_pred_avg

# %%
model, test_probs = train_and_evaluate_seq_only()
# Out:
# Loading structural data...
# phi features shape: (8853, 2)
# psi features shape: (8853, 2)
# omega features shape: (8853, 2)
# SASA features shape: (8853, 3)
# chi1 features shape: (8853, 2)
# chi2 features shape: (8853, 2)
# chi3 features shape: (8853, 2)
# chi4 features shape: (8853, 2)
# SS features shape: (8853, 3)
# plDDT features shape: (8853, 1)
#
# Final combined features shape: (8853, 21)
# Feature list lengths: [2, 2, 2, 3, 2, 2, 2, 2, 3, 1]
# phi features shape: (2737, 2)
# psi features shape: (2737, 2)
# omega features shape: (2737, 2)
# SASA features shape: (2737, 3)
# chi1 features shape: (2737, 2)
# chi2 features shape: (2737, 2)
# chi3 features shape: (2737, 2)
# chi4 features shape: (2737, 2)
# SS features shape: (2737, 3)
# plDDT features shape: (2737, 1)
#
# Final combined features shape: (2737, 21)
# Feature list lengths: [2, 2, 2, 3, 2, 2, 2, 2, 3, 1]
# Training data shape: (8853, 21)
# Testing data shape: (2737, 21)
# Class weights: {0: 1.0388406477352734, 1: 0.9639590592334495}
#
# Fold 1/5
# I0000 00:00:1744130626.146673  981643 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 503 MB memory:  -> device: 0, name: Tesla V100-PCIE-32GB, pci bus id: 0000:00:06.0, compute capability: 7.0
# Epoch 1/50
# 2025-04-08 16:43:46.802399: E tensorflow/core/framework/node_def_util.cc:676] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_16}}
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.5418 - loss: 0.8152 - val_accuracy: 0.6217 - val_loss: 0.6592 - learning_rate: 0.0010
# Epoch 2/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5691 - loss: 0.7103 - val_accuracy: 0.6093 - val_loss: 0.6516 - learning_rate: 0.0010
# Epoch 3/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5733 - loss: 0.6956 - val_accuracy: 0.6064 - val_loss: 0.6493 - learning_rate: 0.0010
# Epoch 4/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5930 - loss: 0.6687 - val_accuracy: 0.6160 - val_loss: 0.6479 - learning_rate: 0.0010
# Epoch 5/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5972 - loss: 0.6661 - val_accuracy: 0.6149 - val_loss: 0.6490 - learning_rate: 0.0010
# Epoch 6/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5978 - loss: 0.6635 - val_accuracy: 0.6183 - val_loss: 0.6483 - learning_rate: 0.0010
# Epoch 7/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6092 - loss: 0.6593 - val_accuracy: 0.6149 - val_loss: 0.6492 - learning_rate: 0.0010
# Epoch 8/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6152 - loss: 0.6583 - val_accuracy: 0.6166 - val_loss: 0.6479 - learning_rate: 0.0010
# Epoch 9/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6175 - loss: 0.6552 - val_accuracy: 0.6121 - val_loss: 0.6477 - learning_rate: 0.0010
# Epoch 10/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6150 - loss: 0.6541 - val_accuracy: 0.6194 - val_loss: 0.6473 - learning_rate: 0.0010
# Epoch 11/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6192 - loss: 0.6502 - val_accuracy: 0.6155 - val_loss: 0.6476 - learning_rate: 0.0010
# Epoch 12/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6183 - loss: 0.6493 - val_accuracy: 0.6132 - val_loss: 0.6477 - learning_rate: 0.0010
# Epoch 13/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6274 - loss: 0.6498 - val_accuracy: 0.6121 - val_loss: 0.6472 - learning_rate: 0.0010
# Epoch 14/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6233 - loss: 0.6514 - val_accuracy: 0.6081 - val_loss: 0.6490 - learning_rate: 0.0010
# Epoch 15/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6084 - loss: 0.6525 - val_accuracy: 0.6172 - val_loss: 0.6495 - learning_rate: 0.0010
# Epoch 16/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6279 - loss: 0.6471 - val_accuracy: 0.6172 - val_loss: 0.6478 - learning_rate: 0.0010
# Epoch 17/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6265 - loss: 0.6454 - val_accuracy: 0.6121 - val_loss: 0.6472 - learning_rate: 0.0010
# Epoch 18/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6306 - loss: 0.6462 - val_accuracy: 0.6047 - val_loss: 0.6492 - learning_rate: 0.0010
# Epoch 19/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6288 - loss: 0.6448 - val_accuracy: 0.6166 - val_loss: 0.6478 - learning_rate: 5.0000e-04
# Epoch 20/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6362 - loss: 0.6383 - val_accuracy: 0.6093 - val_loss: 0.6495 - learning_rate: 5.0000e-04
# Epoch 21/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6332 - loss: 0.6418 - val_accuracy: 0.6132 - val_loss: 0.6485 - learning_rate: 5.0000e-04
# Epoch 22/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6312 - loss: 0.6421 - val_accuracy: 0.6098 - val_loss: 0.6495 - learning_rate: 5.0000e-04
# Epoch 23/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6319 - loss: 0.6391 - val_accuracy: 0.6093 - val_loss: 0.6496 - learning_rate: 5.0000e-04
# Epoch 24/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6306 - loss: 0.6386 - val_accuracy: 0.6110 - val_loss: 0.6499 - learning_rate: 2.5000e-04
# Epoch 25/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6373 - loss: 0.6365 - val_accuracy: 0.6149 - val_loss: 0.6505 - learning_rate: 2.5000e-04
# Epoch 26/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6314 - loss: 0.6374 - val_accuracy: 0.6172 - val_loss: 0.6505 - learning_rate: 2.5000e-04
# Epoch 27/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6335 - loss: 0.6384 - val_accuracy: 0.6110 - val_loss: 0.6513 - learning_rate: 2.5000e-04
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2025-04-08 16:44:24.831625: E tensorflow/core/framework/node_def_util.cc:676] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#
# Fold 1 Results:
# Accuracy: 0.6121
# Balanced Accuracy: 0.6087
# MCC: 0.2212
# Sensitivity: 0.6986
# Specificity: 0.5188
#
# Fold 2/5
# Epoch 1/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.5195 - loss: 0.8291 - val_accuracy: 0.6132 - val_loss: 0.6600 - learning_rate: 0.0010
# Epoch 2/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5818 - loss: 0.6937 - val_accuracy: 0.6115 - val_loss: 0.6538 - learning_rate: 0.0010
# Epoch 3/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5810 - loss: 0.6781 - val_accuracy: 0.6110 - val_loss: 0.6514 - learning_rate: 0.0010
# Epoch 4/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5919 - loss: 0.6700 - val_accuracy: 0.6160 - val_loss: 0.6496 - learning_rate: 0.0010
# Epoch 5/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6018 - loss: 0.6618 - val_accuracy: 0.6172 - val_loss: 0.6502 - learning_rate: 0.0010
# Epoch 6/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5994 - loss: 0.6604 - val_accuracy: 0.6155 - val_loss: 0.6503 - learning_rate: 0.0010
# Epoch 7/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6072 - loss: 0.6550 - val_accuracy: 0.6200 - val_loss: 0.6513 - learning_rate: 0.0010
# Epoch 8/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6121 - loss: 0.6532 - val_accuracy: 0.6200 - val_loss: 0.6509 - learning_rate: 0.0010
# Epoch 9/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6137 - loss: 0.6525 - val_accuracy: 0.6211 - val_loss: 0.6499 - learning_rate: 0.0010
# Epoch 10/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6084 - loss: 0.6550 - val_accuracy: 0.6200 - val_loss: 0.6492 - learning_rate: 5.0000e-04
# Epoch 11/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6312 - loss: 0.6490 - val_accuracy: 0.6194 - val_loss: 0.6484 - learning_rate: 5.0000e-04
# Epoch 12/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6125 - loss: 0.6530 - val_accuracy: 0.6245 - val_loss: 0.6485 - learning_rate: 5.0000e-04
# Epoch 13/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6101 - loss: 0.6540 - val_accuracy: 0.6273 - val_loss: 0.6486 - learning_rate: 5.0000e-04
# Epoch 14/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.6169 - loss: 0.6484 - val_accuracy: 0.6296 - val_loss: 0.6482 - learning_rate: 5.0000e-04
# Epoch 15/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6282 - loss: 0.6454 - val_accuracy: 0.6256 - val_loss: 0.6483 - learning_rate: 5.0000e-04
# Epoch 16/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6223 - loss: 0.6492 - val_accuracy: 0.6273 - val_loss: 0.6482 - learning_rate: 5.0000e-04
# Epoch 17/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6162 - loss: 0.6490 - val_accuracy: 0.6268 - val_loss: 0.6486 - learning_rate: 5.0000e-04
# Epoch 18/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6223 - loss: 0.6460 - val_accuracy: 0.6279 - val_loss: 0.6490 - learning_rate: 5.0000e-04
# Epoch 19/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6242 - loss: 0.6472 - val_accuracy: 0.6273 - val_loss: 0.6487 - learning_rate: 5.0000e-04
# Epoch 20/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6248 - loss: 0.6486 - val_accuracy: 0.6296 - val_loss: 0.6486 - learning_rate: 2.5000e-04
# Epoch 21/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6266 - loss: 0.6461 - val_accuracy: 0.6307 - val_loss: 0.6487 - learning_rate: 2.5000e-04
# Epoch 22/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6220 - loss: 0.6477 - val_accuracy: 0.6318 - val_loss: 0.6487 - learning_rate: 2.5000e-04
# Epoch 23/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.6253 - loss: 0.6425 - val_accuracy: 0.6318 - val_loss: 0.6489 - learning_rate: 2.5000e-04
# Epoch 24/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6189 - loss: 0.6428 - val_accuracy: 0.6279 - val_loss: 0.6484 - learning_rate: 2.5000e-04
# Epoch 25/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6279 - loss: 0.6450 - val_accuracy: 0.6285 - val_loss: 0.6484 - learning_rate: 1.2500e-04
# Epoch 26/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6298 - loss: 0.6422 - val_accuracy: 0.6279 - val_loss: 0.6481 - learning_rate: 1.2500e-04
# Epoch 27/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6245 - loss: 0.6456 - val_accuracy: 0.6279 - val_loss: 0.6485 - learning_rate: 1.2500e-04
# Epoch 28/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6158 - loss: 0.6445 - val_accuracy: 0.6251 - val_loss: 0.6488 - learning_rate: 1.2500e-04
# Epoch 29/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6355 - loss: 0.6423 - val_accuracy: 0.6285 - val_loss: 0.6489 - learning_rate: 1.2500e-04
# Epoch 30/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6254 - loss: 0.6432 - val_accuracy: 0.6285 - val_loss: 0.6489 - learning_rate: 6.2500e-05
# Epoch 31/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6308 - loss: 0.6418 - val_accuracy: 0.6273 - val_loss: 0.6488 - learning_rate: 6.2500e-05
# Epoch 32/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6258 - loss: 0.6445 - val_accuracy: 0.6268 - val_loss: 0.6488 - learning_rate: 6.2500e-05
# Epoch 33/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6315 - loss: 0.6422 - val_accuracy: 0.6262 - val_loss: 0.6487 - learning_rate: 6.2500e-05
# Epoch 34/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6297 - loss: 0.6407 - val_accuracy: 0.6256 - val_loss: 0.6486 - learning_rate: 6.2500e-05
# Epoch 35/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6277 - loss: 0.6453 - val_accuracy: 0.6268 - val_loss: 0.6486 - learning_rate: 3.1250e-05
# Epoch 36/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6198 - loss: 0.6455 - val_accuracy: 0.6279 - val_loss: 0.6486 - learning_rate: 3.1250e-05
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2025-04-08 16:45:17.430233: E tensorflow/core/framework/node_def_util.cc:676] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#
# Fold 2 Results:
# Accuracy: 0.6279
# Balanced Accuracy: 0.6264
# MCC: 0.2536
# Sensitivity: 0.6649
# Specificity: 0.5880
#
# Fold 3/5
# Epoch 1/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.5381 - loss: 0.8256 - val_accuracy: 0.5280 - val_loss: 0.6849 - learning_rate: 0.0010
# Epoch 2/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5684 - loss: 0.7246 - val_accuracy: 0.6047 - val_loss: 0.6576 - learning_rate: 0.0010
# Epoch 3/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5796 - loss: 0.6940 - val_accuracy: 0.6143 - val_loss: 0.6540 - learning_rate: 0.0010
# Epoch 4/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5840 - loss: 0.6814 - val_accuracy: 0.6239 - val_loss: 0.6521 - learning_rate: 0.0010
# Epoch 5/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5889 - loss: 0.6738 - val_accuracy: 0.6070 - val_loss: 0.6515 - learning_rate: 0.0010
# Epoch 6/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5954 - loss: 0.6593 - val_accuracy: 0.6194 - val_loss: 0.6514 - learning_rate: 0.0010
# Epoch 7/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6082 - loss: 0.6621 - val_accuracy: 0.6166 - val_loss: 0.6511 - learning_rate: 0.0010
# Epoch 8/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6044 - loss: 0.6638 - val_accuracy: 0.6245 - val_loss: 0.6491 - learning_rate: 0.0010
# Epoch 9/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6091 - loss: 0.6568 - val_accuracy: 0.6273 - val_loss: 0.6488 - learning_rate: 0.0010
# Epoch 10/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6113 - loss: 0.6518 - val_accuracy: 0.6273 - val_loss: 0.6479 - learning_rate: 0.0010
# Epoch 11/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6142 - loss: 0.6525 - val_accuracy: 0.6251 - val_loss: 0.6472 - learning_rate: 0.0010
# Epoch 12/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6097 - loss: 0.6547 - val_accuracy: 0.6290 - val_loss: 0.6479 - learning_rate: 0.0010
# Epoch 13/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6124 - loss: 0.6517 - val_accuracy: 0.6239 - val_loss: 0.6483 - learning_rate: 0.0010
# Epoch 14/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6139 - loss: 0.6472 - val_accuracy: 0.6251 - val_loss: 0.6475 - learning_rate: 0.0010
# Epoch 15/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6229 - loss: 0.6467 - val_accuracy: 0.6239 - val_loss: 0.6493 - learning_rate: 0.0010
# Epoch 16/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6192 - loss: 0.6481 - val_accuracy: 0.6239 - val_loss: 0.6485 - learning_rate: 0.0010
# Epoch 17/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6211 - loss: 0.6464 - val_accuracy: 0.6222 - val_loss: 0.6486 - learning_rate: 5.0000e-04
# Epoch 18/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6321 - loss: 0.6439 - val_accuracy: 0.6183 - val_loss: 0.6478 - learning_rate: 5.0000e-04
# Epoch 19/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.6231 - loss: 0.6459 - val_accuracy: 0.6217 - val_loss: 0.6471 - learning_rate: 5.0000e-04
# Epoch 20/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6258 - loss: 0.6425 - val_accuracy: 0.6245 - val_loss: 0.6482 - learning_rate: 5.0000e-04
# Epoch 21/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6313 - loss: 0.6408 - val_accuracy: 0.6234 - val_loss: 0.6481 - learning_rate: 5.0000e-04
# Epoch 22/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6247 - loss: 0.6425 - val_accuracy: 0.6217 - val_loss: 0.6480 - learning_rate: 2.5000e-04
# Epoch 23/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6243 - loss: 0.6431 - val_accuracy: 0.6256 - val_loss: 0.6478 - learning_rate: 2.5000e-04
# Epoch 24/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6242 - loss: 0.6416 - val_accuracy: 0.6217 - val_loss: 0.6482 - learning_rate: 2.5000e-04
# Epoch 25/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6255 - loss: 0.6400 - val_accuracy: 0.6251 - val_loss: 0.6486 - learning_rate: 2.5000e-04
# Epoch 26/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6172 - loss: 0.6431 - val_accuracy: 0.6239 - val_loss: 0.6485 - learning_rate: 2.5000e-04
# Epoch 27/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6306 - loss: 0.6387 - val_accuracy: 0.6183 - val_loss: 0.6482 - learning_rate: 1.2500e-04
# Epoch 28/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6347 - loss: 0.6417 - val_accuracy: 0.6234 - val_loss: 0.6481 - learning_rate: 1.2500e-04
# Epoch 29/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6370 - loss: 0.6371 - val_accuracy: 0.6222 - val_loss: 0.6486 - learning_rate: 1.2500e-04
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2025-04-08 16:45:58.595086: E tensorflow/core/framework/node_def_util.cc:676] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#
# Fold 3 Results:
# Accuracy: 0.6217
# Balanced Accuracy: 0.6203
# MCC: 0.2413
# Sensitivity: 0.6590
# Specificity: 0.5815
#
# Fold 4/5
# Epoch 1/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.5590 - loss: 0.8337 - val_accuracy: 0.6051 - val_loss: 0.6703 - learning_rate: 0.0010
# Epoch 2/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5626 - loss: 0.7310 - val_accuracy: 0.6017 - val_loss: 0.6649 - learning_rate: 0.0010
# Epoch 3/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5839 - loss: 0.6906 - val_accuracy: 0.5927 - val_loss: 0.6620 - learning_rate: 0.0010
# Epoch 4/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5920 - loss: 0.6795 - val_accuracy: 0.6006 - val_loss: 0.6605 - learning_rate: 0.0010
# Epoch 5/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6077 - loss: 0.6665 - val_accuracy: 0.5927 - val_loss: 0.6615 - learning_rate: 0.0010
# Epoch 6/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6052 - loss: 0.6576 - val_accuracy: 0.5960 - val_loss: 0.6602 - learning_rate: 0.0010
# Epoch 7/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6173 - loss: 0.6578 - val_accuracy: 0.5972 - val_loss: 0.6602 - learning_rate: 0.0010
# Epoch 8/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6080 - loss: 0.6556 - val_accuracy: 0.5994 - val_loss: 0.6599 - learning_rate: 0.0010
# Epoch 9/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6254 - loss: 0.6524 - val_accuracy: 0.6023 - val_loss: 0.6594 - learning_rate: 0.0010
# Epoch 10/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6205 - loss: 0.6515 - val_accuracy: 0.6062 - val_loss: 0.6593 - learning_rate: 0.0010
# Epoch 11/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6301 - loss: 0.6521 - val_accuracy: 0.6085 - val_loss: 0.6586 - learning_rate: 0.0010
# Epoch 12/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6190 - loss: 0.6495 - val_accuracy: 0.6017 - val_loss: 0.6586 - learning_rate: 0.0010
# Epoch 13/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6160 - loss: 0.6474 - val_accuracy: 0.6090 - val_loss: 0.6592 - learning_rate: 0.0010
# Epoch 14/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6143 - loss: 0.6491 - val_accuracy: 0.5989 - val_loss: 0.6602 - learning_rate: 0.0010
# Epoch 15/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6250 - loss: 0.6486 - val_accuracy: 0.6040 - val_loss: 0.6594 - learning_rate: 0.0010
# Epoch 16/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6321 - loss: 0.6457 - val_accuracy: 0.6045 - val_loss: 0.6598 - learning_rate: 0.0010
# Epoch 17/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6296 - loss: 0.6439 - val_accuracy: 0.6073 - val_loss: 0.6607 - learning_rate: 5.0000e-04
# Epoch 18/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6309 - loss: 0.6444 - val_accuracy: 0.6017 - val_loss: 0.6611 - learning_rate: 5.0000e-04
# Epoch 19/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.6278 - loss: 0.6420 - val_accuracy: 0.6062 - val_loss: 0.6608 - learning_rate: 5.0000e-04
# Epoch 20/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.6301 - loss: 0.6436 - val_accuracy: 0.6051 - val_loss: 0.6621 - learning_rate: 5.0000e-04
# Epoch 21/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6292 - loss: 0.6450 - val_accuracy: 0.6017 - val_loss: 0.6602 - learning_rate: 5.0000e-04
# Epoch 22/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6270 - loss: 0.6401 - val_accuracy: 0.6006 - val_loss: 0.6609 - learning_rate: 2.5000e-04
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2025-04-08 16:46:31.980845: E tensorflow/core/framework/node_def_util.cc:676] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#
# Fold 4 Results:
# Accuracy: 0.6017
# Balanced Accuracy: 0.5989
# MCC: 0.2002
# Sensitivity: 0.6732
# Specificity: 0.5246
#
# Fold 5/5
# Epoch 1/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.5257 - loss: 0.8416 - val_accuracy: 0.5695 - val_loss: 0.6730 - learning_rate: 0.0010
# Epoch 2/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5766 - loss: 0.7167 - val_accuracy: 0.5847 - val_loss: 0.6656 - learning_rate: 0.0010
# Epoch 3/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5900 - loss: 0.6811 - val_accuracy: 0.5898 - val_loss: 0.6654 - learning_rate: 0.0010
# Epoch 4/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.6095 - loss: 0.6604 - val_accuracy: 0.5870 - val_loss: 0.6646 - learning_rate: 0.0010
# Epoch 5/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6091 - loss: 0.6611 - val_accuracy: 0.5853 - val_loss: 0.6628 - learning_rate: 0.0010
# Epoch 6/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6033 - loss: 0.6612 - val_accuracy: 0.5927 - val_loss: 0.6614 - learning_rate: 0.0010
# Epoch 7/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6170 - loss: 0.6535 - val_accuracy: 0.5938 - val_loss: 0.6617 - learning_rate: 0.0010
# Epoch 8/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6161 - loss: 0.6488 - val_accuracy: 0.5921 - val_loss: 0.6606 - learning_rate: 0.0010
# Epoch 9/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6225 - loss: 0.6485 - val_accuracy: 0.5938 - val_loss: 0.6614 - learning_rate: 0.0010
# Epoch 10/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6232 - loss: 0.6474 - val_accuracy: 0.5938 - val_loss: 0.6591 - learning_rate: 0.0010
# Epoch 11/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6279 - loss: 0.6461 - val_accuracy: 0.5938 - val_loss: 0.6591 - learning_rate: 0.0010
# Epoch 12/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6301 - loss: 0.6439 - val_accuracy: 0.5944 - val_loss: 0.6598 - learning_rate: 0.0010
# Epoch 13/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6342 - loss: 0.6419 - val_accuracy: 0.5921 - val_loss: 0.6593 - learning_rate: 0.0010
# Epoch 14/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6279 - loss: 0.6415 - val_accuracy: 0.5932 - val_loss: 0.6586 - learning_rate: 0.0010
# Epoch 15/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6309 - loss: 0.6401 - val_accuracy: 0.5955 - val_loss: 0.6604 - learning_rate: 0.0010
# Epoch 16/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6292 - loss: 0.6415 - val_accuracy: 0.6017 - val_loss: 0.6597 - learning_rate: 0.0010
# Epoch 17/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6327 - loss: 0.6414 - val_accuracy: 0.6006 - val_loss: 0.6600 - learning_rate: 0.0010
# Epoch 18/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6261 - loss: 0.6399 - val_accuracy: 0.6073 - val_loss: 0.6593 - learning_rate: 0.0010
# Epoch 19/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6272 - loss: 0.6392 - val_accuracy: 0.5938 - val_loss: 0.6592 - learning_rate: 0.0010
# Epoch 20/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.6304 - loss: 0.6417 - val_accuracy: 0.6017 - val_loss: 0.6585 - learning_rate: 5.0000e-04
# Epoch 21/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6377 - loss: 0.6362 - val_accuracy: 0.5938 - val_loss: 0.6586 - learning_rate: 5.0000e-04
# Epoch 22/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6304 - loss: 0.6392 - val_accuracy: 0.6017 - val_loss: 0.6581 - learning_rate: 5.0000e-04
# Epoch 23/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6284 - loss: 0.6373 - val_accuracy: 0.5955 - val_loss: 0.6587 - learning_rate: 5.0000e-04
# Epoch 24/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6370 - loss: 0.6356 - val_accuracy: 0.5983 - val_loss: 0.6584 - learning_rate: 5.0000e-04
# Epoch 25/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6335 - loss: 0.6346 - val_accuracy: 0.5966 - val_loss: 0.6591 - learning_rate: 5.0000e-04
# Epoch 26/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6395 - loss: 0.6341 - val_accuracy: 0.6023 - val_loss: 0.6600 - learning_rate: 5.0000e-04
# Epoch 27/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6293 - loss: 0.6399 - val_accuracy: 0.5994 - val_loss: 0.6586 - learning_rate: 5.0000e-04
# Epoch 28/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6440 - loss: 0.6302 - val_accuracy: 0.5944 - val_loss: 0.6599 - learning_rate: 2.5000e-04
# Epoch 29/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6384 - loss: 0.6319 - val_accuracy: 0.5989 - val_loss: 0.6603 - learning_rate: 2.5000e-04
# Epoch 30/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6456 - loss: 0.6339 - val_accuracy: 0.5938 - val_loss: 0.6599 - learning_rate: 2.5000e-04
# Epoch 31/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6384 - loss: 0.6321 - val_accuracy: 0.6017 - val_loss: 0.6592 - learning_rate: 2.5000e-04
# Epoch 32/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6361 - loss: 0.6351 - val_accuracy: 0.5989 - val_loss: 0.6598 - learning_rate: 2.5000e-04
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2025-04-08 16:47:17.799465: E tensorflow/core/framework/node_def_util.cc:676] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#
# Fold 5 Results:
# Accuracy: 0.6017
# Balanced Accuracy: 0.6006
# MCC: 0.2015
# Sensitivity: 0.6307
# Specificity: 0.5704
#
# Average Cross-validation Results:
# ACC: 0.6130 ± 0.0105
# BALANCED_ACC: 0.6110 ± 0.0108
# MCC: 0.2235 ± 0.0213
# SN: 0.6653 ± 0.0219
# SP: 0.5567 ± 0.0292
#
# Final Test Set Results:
# Accuracy: 0.4984
# Balanced Accuracy: 0.5914
# MCC: 0.1037
# Sensitivity: 0.7042
# Specificity: 0.4786
# Confusion Matrix:
# [[1195 1302]
#  [  71  169]]
