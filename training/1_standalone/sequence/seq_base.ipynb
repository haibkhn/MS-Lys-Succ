# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix, matthews_corrcoef, accuracy_score, balanced_accuracy_score
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.preprocessing import RobustScaler
import matplotlib.pyplot as plt
import random
# Out:
# 2025-04-08 09:27:44.668779: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744104464.688950  837565 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744104464.694851  837565 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-08 09:27:44.717232: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Set random seeds for reproducibility
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
tf.keras.utils.set_random_seed(SEED)  # This sets all random seeds in keras
tf.config.experimental.enable_op_determinism()  # For complete reproducibility

# %%
def load_prot_t5_data(pos_file, neg_file):
    """Load ProtT5 embeddings and align with existing data"""
    # Read positive and negative files
    pos_data = []
    with open(pos_file, 'r') as f:
        for line in f:
            parts = line.strip().split(',')
            entry = parts[0]
            pos = int(parts[1])
            embeddings = [float(x) for x in parts[2:]]
            pos_data.append((entry, pos, embeddings))
            
    neg_data = []
    with open(neg_file, 'r') as f:
        for line in f:
            parts = line.strip().split(',')
            entry = parts[0]
            pos = int(parts[1])
            embeddings = [float(x) for x in parts[2:]]
            neg_data.append((entry, pos, embeddings))
    
    # Convert to dictionaries for easy lookup
    pos_dict = {(entry, pos): emb for entry, pos, emb in pos_data}
    neg_dict = {(entry, pos): emb for entry, pos, emb in neg_data}
    
    return pos_dict, neg_dict

# %%
def prepare_aligned_data(seq_struct_df, pos_dict, neg_dict):
    """Align ProtT5 embeddings with sequence+structure data"""
    embeddings = []
    aligned_indices = []
    
    for idx, row in seq_struct_df.iterrows():
        key = (row['entry'], row['pos'])
        emb = pos_dict.get(key) if row['label'] == 1 else neg_dict.get(key)
        
        if emb is not None:
            embeddings.append(emb)
            aligned_indices.append(idx)
    
    # Convert to numpy array
    X_prot_t5 = np.array(embeddings)
    
    # Get aligned sequence+structure data
    aligned_df = seq_struct_df.iloc[aligned_indices]
    
    return X_prot_t5, aligned_df

# %%
from Bio import SeqIO

def get_input_for_embedding(fasta_file):
    encodings = []
    
    # define universe of possible input values
    alphabet = 'ARNDCQEGHILKMFPSTWYV-'
    
    # define a mapping of chars to integers
    char_to_int = dict((c, i) for i, c in enumerate(alphabet))
    int_to_char = dict((i, c) for i, c in enumerate(alphabet))
    
    for seq_record in SeqIO.parse(fasta_file, "fasta"):
        data = seq_record.seq
        for char in data:
            if char not in alphabet:
                return
        integer_encoded = [char_to_int[char] for char in data]
        encodings.append(integer_encoded)
    encodings = np.array(encodings)
    return encodings

# %%
def create_sequence_model():
    """Create CNN model for sequence data"""
    model = tf.keras.Sequential([
        tf.keras.layers.Input(shape=(33,)),
        tf.keras.layers.Embedding(21, 21, input_length=33),
        tf.keras.layers.Reshape((33, 21, 1)),
        tf.keras.layers.Conv2D(32, kernel_size=(17, 3), activation='relu', padding='valid'),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(32, activation='relu'),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    return model

# %%
def print_metrics(y_true, y_pred):
    """
    Print comprehensive evaluation metrics
    
    Parameters:
    y_true: array-like of true labels
    y_pred: array-like of predicted labels
    """
    # Calculate confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    
    # Calculate metrics
    acc = accuracy_score(y_true, y_pred)
    balanced_acc = balanced_accuracy_score(y_true, y_pred)
    mcc = matthews_corrcoef(y_true, y_pred)
    sensitivity = cm[1][1] / (cm[1][1] + cm[1][0])  # True Positive Rate
    specificity = cm[0][0] / (cm[0][0] + cm[0][1])  # True Negative Rate
    
    # Print results
    print(f"Accuracy: {acc:.4f}")
    print(f"Balanced Accuracy: {balanced_acc:.4f}")
    print(f"MCC: {mcc:.4f}")
    print(f"Sensitivity: {sensitivity:.4f}")
    print(f"Specificity: {specificity:.4f}")
    print("Confusion Matrix:")
    print(cm)

# %%
def train_and_evaluate_seq_only():
    """Training function for sequence-only model using FASTA files"""
    # Load data from FASTA files
    print("Loading data from FASTA files...")
    train_positive_embedding = get_input_for_embedding('../../../data/train/fasta/positive_sites.fasta')
    train_negative_embedding = get_input_for_embedding('../../../data/train/fasta/negative_sites.fasta')
    test_positive_embedding = get_input_for_embedding('../../../data/test/fasta/test_positive_sites.fasta')
    test_negative_embedding = get_input_for_embedding('../../../data/test/fasta/test_negative_sites.fasta')
    
    # Check if any of the files couldn't be loaded
    if train_positive_embedding is None or train_negative_embedding is None or \
       test_positive_embedding is None or test_negative_embedding is None:
        print("Error: Could not load one or more FASTA files. Check for non-standard amino acids.")
        return
    
    # Create labels for positive and negative samples
    train_positive_labels = np.ones(len(train_positive_embedding))
    train_negative_labels = np.zeros(len(train_negative_embedding))
    test_positive_labels = np.ones(len(test_positive_embedding))
    test_negative_labels = np.zeros(len(test_negative_embedding))
    
    # Combine positive and negative samples
    X_train_seq = np.vstack((train_positive_embedding, train_negative_embedding))
    y_train = np.concatenate((train_positive_labels, train_negative_labels))
    
    X_test_seq = np.vstack((test_positive_embedding, test_negative_embedding))
    y_test = np.concatenate((test_positive_labels, test_negative_labels))
    
    # Shuffle training data
    shuffle_idx = np.random.RandomState(42).permutation(len(y_train))
    X_train_seq = X_train_seq[shuffle_idx]
    y_train = y_train[shuffle_idx]
    
    # Calculate class weights
    total_samples = len(y_train)
    pos_samples = np.sum(y_train == 1)
    neg_samples = np.sum(y_train == 0)
    
    class_weights = {
        0: total_samples / (2 * neg_samples),
        1: total_samples / (2 * pos_samples)
    }
    
    print(f"Training data shape: {X_train_seq.shape}")
    print(f"Testing data shape: {X_test_seq.shape}")
    print(f"Class weights: {class_weights}")
    
    # Cross-validation setup
    kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    metrics = {'acc': [], 'balanced_acc': [], 'mcc': [], 'sn': [], 'sp': []}
    test_predictions = []
    
    for fold, (train_idx, val_idx) in enumerate(kfold.split(X_train_seq, y_train), 1):
        print(f"\nFold {fold}/5")
        
        # Callbacks
        callbacks = [
            tf.keras.callbacks.EarlyStopping(
                monitor='val_loss',
                patience=10,
                restore_best_weights=True
            ),
            tf.keras.callbacks.ReduceLROnPlateau(
                monitor='val_loss',
                factor=0.5,
                patience=5,
                min_lr=1e-6
            )
        ]
        
        # Create and compile model
        model = create_sequence_model()
        model.compile(
            optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
            loss='binary_crossentropy',
            metrics=['accuracy']
        )
        
        # Train model
        history = model.fit(
            X_train_seq[train_idx], 
            y_train[train_idx],
            validation_data=(
                X_train_seq[val_idx], 
                y_train[val_idx]
            ),
            batch_size=32,
            epochs=50,
            callbacks=callbacks,
            class_weight=class_weights,
            verbose=1
        )
        
        # Plot training history
        plt.figure(figsize=(10, 6))
        plt.plot(history.history['accuracy'], label='Train Accuracy')
        plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
        plt.title(f'Model Accuracy - Fold {fold}')
        plt.xlabel('Epoch')
        plt.ylabel('Accuracy')
        plt.legend()
        plt.show()
        
        # Evaluate on validation set
        val_pred = model.predict(X_train_seq[val_idx])
        val_pred_binary = (val_pred > 0.5).astype(int)
        
        # Calculate metrics
        cm = confusion_matrix(y_train[val_idx], val_pred_binary)
        metrics['acc'].append(accuracy_score(y_train[val_idx], val_pred_binary))
        metrics['balanced_acc'].append(balanced_accuracy_score(y_train[val_idx], val_pred_binary))
        metrics['mcc'].append(matthews_corrcoef(y_train[val_idx], val_pred_binary))
        metrics['sn'].append(cm[1][1]/(cm[1][1]+cm[1][0]))
        metrics['sp'].append(cm[0][0]/(cm[0][0]+cm[0][1]))
        
        # Predict on test set
        test_pred = model.predict(X_test_seq)
        test_predictions.append(test_pred)
        
        print(f"\nFold {fold} Results:")
        print(f"Accuracy: {metrics['acc'][-1]:.4f}")
        print(f"Balanced Accuracy: {metrics['balanced_acc'][-1]:.4f}")
        print(f"MCC: {metrics['mcc'][-1]:.4f}")
        print(f"Sensitivity: {metrics['sn'][-1]:.4f}")
        print(f"Specificity: {metrics['sp'][-1]:.4f}")
    
    # Print average cross-validation results
    print("\nAverage Cross-validation Results:")
    for metric in metrics:
        print(f"{metric.upper()}: {np.mean(metrics[metric]):.4f} ± {np.std(metrics[metric]):.4f}")
    
    # Ensemble predictions on test set
    test_pred_avg = np.mean(test_predictions, axis=0)
    test_pred_binary = (test_pred_avg > 0.5).astype(int)
    
    # Calculate final test metrics
    cm_test = confusion_matrix(y_test, test_pred_binary)
    
    print("\nFinal Test Set Results:")
    print(f"Accuracy: {accuracy_score(y_test, test_pred_binary):.4f}")
    print(f"Balanced Accuracy: {balanced_accuracy_score(y_test, test_pred_binary):.4f}")
    print(f"MCC: {matthews_corrcoef(y_test, test_pred_binary):.4f}")
    print(f"Sensitivity: {cm_test[1][1]/(cm_test[1][1]+cm_test[1][0]):.4f}")
    print(f"Specificity: {cm_test[0][0]/(cm_test[0][0]+cm_test[0][1]):.4f}")
    print("Confusion Matrix:")
    print(cm_test)
    
    return model, test_pred_avg

# %%
model, test_probs = train_and_evaluate_seq_only()
# Out:
# Loading data from FASTA files...
# Training data shape: (9500, 33)
# Testing data shape: (3224, 33)
# Class weights: {0: 1.0, 1: 1.0}
#
# Fold 1/5
# /home/ubuntu/data/miniconda3/envs/finetune-dephos/lib/python3.9/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# I0000 00:00:1744104485.182089  837565 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 31134 MB memory:  -> device: 0, name: Tesla V100-PCIE-32GB, pci bus id: 0000:00:06.0, compute capability: 7.0
# Epoch 1/50
# 2025-04-08 09:28:06.655681: E tensorflow/core/framework/node_def_util.cc:676] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_16}}
# E0000 00:00:1744104487.515254  837565 meta_optimizer.cc:966] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inStatefulPartitionedCall/sequential_1/dropout_1/stateless_dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# I0000 00:00:1744104488.135737  837918 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.5078 - loss: 0.6914 - val_accuracy: 0.6395 - val_loss: 0.6401 - learning_rate: 0.0010
# Epoch 2/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6492 - loss: 0.6241 - val_accuracy: 0.7137 - val_loss: 0.5695 - learning_rate: 0.0010
# Epoch 3/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7201 - loss: 0.5611 - val_accuracy: 0.7311 - val_loss: 0.5446 - learning_rate: 0.0010
# Epoch 4/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7373 - loss: 0.5403 - val_accuracy: 0.7353 - val_loss: 0.5363 - learning_rate: 0.0010
# Epoch 5/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7469 - loss: 0.5237 - val_accuracy: 0.7389 - val_loss: 0.5300 - learning_rate: 0.0010
# Epoch 6/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7543 - loss: 0.5125 - val_accuracy: 0.7400 - val_loss: 0.5285 - learning_rate: 0.0010
# Epoch 7/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7671 - loss: 0.4976 - val_accuracy: 0.7474 - val_loss: 0.5241 - learning_rate: 0.0010
# Epoch 8/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7779 - loss: 0.4870 - val_accuracy: 0.7468 - val_loss: 0.5235 - learning_rate: 0.0010
# Epoch 9/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7826 - loss: 0.4783 - val_accuracy: 0.7395 - val_loss: 0.5239 - learning_rate: 0.0010
# Epoch 10/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7839 - loss: 0.4642 - val_accuracy: 0.7474 - val_loss: 0.5212 - learning_rate: 0.0010
# Epoch 11/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7924 - loss: 0.4509 - val_accuracy: 0.7426 - val_loss: 0.5261 - learning_rate: 0.0010
# Epoch 12/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7941 - loss: 0.4455 - val_accuracy: 0.7389 - val_loss: 0.5312 - learning_rate: 0.0010
# Epoch 13/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8151 - loss: 0.4266 - val_accuracy: 0.7300 - val_loss: 0.5432 - learning_rate: 0.0010
# Epoch 14/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8168 - loss: 0.4175 - val_accuracy: 0.7337 - val_loss: 0.5436 - learning_rate: 0.0010
# Epoch 15/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8143 - loss: 0.4092 - val_accuracy: 0.7258 - val_loss: 0.5540 - learning_rate: 0.0010
# Epoch 16/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8271 - loss: 0.3880 - val_accuracy: 0.7342 - val_loss: 0.5498 - learning_rate: 5.0000e-04
# Epoch 17/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8347 - loss: 0.3786 - val_accuracy: 0.7337 - val_loss: 0.5631 - learning_rate: 5.0000e-04
# Epoch 18/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8327 - loss: 0.3796 - val_accuracy: 0.7379 - val_loss: 0.5568 - learning_rate: 5.0000e-04
# Epoch 19/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8430 - loss: 0.3605 - val_accuracy: 0.7374 - val_loss: 0.5592 - learning_rate: 5.0000e-04
# Epoch 20/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8435 - loss: 0.3582 - val_accuracy: 0.7379 - val_loss: 0.5688 - learning_rate: 5.0000e-04
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2025-04-08 09:28:35.696064: E tensorflow/core/framework/node_def_util.cc:676] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#
# Fold 1 Results:
# Accuracy: 0.7474
# Balanced Accuracy: 0.7474
# MCC: 0.4948
# Sensitivity: 0.7537
# Specificity: 0.7411
#
# Fold 2/5
# Epoch 1/50
# /home/ubuntu/data/miniconda3/envs/finetune-dephos/lib/python3.9/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.5150 - loss: 0.6923 - val_accuracy: 0.6311 - val_loss: 0.6488 - learning_rate: 0.0010
# Epoch 2/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6359 - loss: 0.6376 - val_accuracy: 0.7063 - val_loss: 0.5737 - learning_rate: 0.0010
# Epoch 3/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7079 - loss: 0.5789 - val_accuracy: 0.7158 - val_loss: 0.5476 - learning_rate: 0.0010
# Epoch 4/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7324 - loss: 0.5387 - val_accuracy: 0.7358 - val_loss: 0.5277 - learning_rate: 0.0010
# Epoch 5/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7461 - loss: 0.5244 - val_accuracy: 0.7463 - val_loss: 0.5208 - learning_rate: 0.0010
# Epoch 6/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7492 - loss: 0.5124 - val_accuracy: 0.7468 - val_loss: 0.5181 - learning_rate: 0.0010
# Epoch 7/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7602 - loss: 0.4990 - val_accuracy: 0.7500 - val_loss: 0.5153 - learning_rate: 0.0010
# Epoch 8/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7595 - loss: 0.4940 - val_accuracy: 0.7563 - val_loss: 0.5097 - learning_rate: 0.0010
# Epoch 9/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7735 - loss: 0.4795 - val_accuracy: 0.7542 - val_loss: 0.5136 - learning_rate: 0.0010
# Epoch 10/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7771 - loss: 0.4698 - val_accuracy: 0.7563 - val_loss: 0.5108 - learning_rate: 0.0010
# Epoch 11/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7833 - loss: 0.4584 - val_accuracy: 0.7521 - val_loss: 0.5164 - learning_rate: 0.0010
# Epoch 12/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7921 - loss: 0.4484 - val_accuracy: 0.7600 - val_loss: 0.5152 - learning_rate: 0.0010
# Epoch 13/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7886 - loss: 0.4484 - val_accuracy: 0.7537 - val_loss: 0.5210 - learning_rate: 0.0010
# Epoch 14/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8075 - loss: 0.4221 - val_accuracy: 0.7563 - val_loss: 0.5179 - learning_rate: 5.0000e-04
# Epoch 15/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8116 - loss: 0.4177 - val_accuracy: 0.7542 - val_loss: 0.5263 - learning_rate: 5.0000e-04
# Epoch 16/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8151 - loss: 0.4080 - val_accuracy: 0.7516 - val_loss: 0.5333 - learning_rate: 5.0000e-04
# Epoch 17/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8154 - loss: 0.4028 - val_accuracy: 0.7495 - val_loss: 0.5323 - learning_rate: 5.0000e-04
# Epoch 18/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8254 - loss: 0.3889 - val_accuracy: 0.7463 - val_loss: 0.5311 - learning_rate: 5.0000e-04
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2025-04-08 09:28:59.828662: E tensorflow/core/framework/node_def_util.cc:676] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#
# Fold 2 Results:
# Accuracy: 0.7563
# Balanced Accuracy: 0.7563
# MCC: 0.5224
# Sensitivity: 0.8526
# Specificity: 0.6600
#
# Fold 3/5
# Epoch 1/50
# /home/ubuntu/data/miniconda3/envs/finetune-dephos/lib/python3.9/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.5218 - loss: 0.6886 - val_accuracy: 0.6474 - val_loss: 0.6331 - learning_rate: 0.0010
# Epoch 2/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6700 - loss: 0.6047 - val_accuracy: 0.7168 - val_loss: 0.5659 - learning_rate: 0.0010
# Epoch 3/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7397 - loss: 0.5333 - val_accuracy: 0.7268 - val_loss: 0.5490 - learning_rate: 0.0010
# Epoch 4/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7612 - loss: 0.5119 - val_accuracy: 0.7295 - val_loss: 0.5373 - learning_rate: 0.0010
# Epoch 5/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7678 - loss: 0.4931 - val_accuracy: 0.7321 - val_loss: 0.5324 - learning_rate: 0.0010
# Epoch 6/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7748 - loss: 0.4851 - val_accuracy: 0.7368 - val_loss: 0.5308 - learning_rate: 0.0010
# Epoch 7/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7876 - loss: 0.4698 - val_accuracy: 0.7379 - val_loss: 0.5297 - learning_rate: 0.0010
# Epoch 8/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7899 - loss: 0.4582 - val_accuracy: 0.7332 - val_loss: 0.5250 - learning_rate: 0.0010
# Epoch 9/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7991 - loss: 0.4446 - val_accuracy: 0.7289 - val_loss: 0.5261 - learning_rate: 0.0010
# Epoch 10/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8070 - loss: 0.4272 - val_accuracy: 0.7300 - val_loss: 0.5304 - learning_rate: 0.0010
# Epoch 11/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8148 - loss: 0.4178 - val_accuracy: 0.7253 - val_loss: 0.5310 - learning_rate: 0.0010
# Epoch 12/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8263 - loss: 0.3882 - val_accuracy: 0.7179 - val_loss: 0.5349 - learning_rate: 0.0010
# Epoch 13/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8271 - loss: 0.3832 - val_accuracy: 0.7195 - val_loss: 0.5414 - learning_rate: 0.0010
# Epoch 14/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8388 - loss: 0.3643 - val_accuracy: 0.7184 - val_loss: 0.5526 - learning_rate: 5.0000e-04
# Epoch 15/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8480 - loss: 0.3575 - val_accuracy: 0.7205 - val_loss: 0.5507 - learning_rate: 5.0000e-04
# Epoch 16/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8519 - loss: 0.3421 - val_accuracy: 0.7153 - val_loss: 0.5640 - learning_rate: 5.0000e-04
# Epoch 17/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8521 - loss: 0.3384 - val_accuracy: 0.7216 - val_loss: 0.5618 - learning_rate: 5.0000e-04
# Epoch 18/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8592 - loss: 0.3231 - val_accuracy: 0.7158 - val_loss: 0.5647 - learning_rate: 5.0000e-04
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2025-04-08 09:29:24.159451: E tensorflow/core/framework/node_def_util.cc:676] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#
# Fold 3 Results:
# Accuracy: 0.7332
# Balanced Accuracy: 0.7332
# MCC: 0.4668
# Sensitivity: 0.7568
# Specificity: 0.7095
#
# Fold 4/5
# Epoch 1/50
# /home/ubuntu/data/miniconda3/envs/finetune-dephos/lib/python3.9/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
#  26/238 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5191 - loss: 0.6942
# E0000 00:00:1744104565.619065  837565 meta_optimizer.cc:966] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inStatefulPartitionedCall/sequential_3_1/dropout_6_1/stateless_dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.5337 - loss: 0.6875 - val_accuracy: 0.6532 - val_loss: 0.6299 - learning_rate: 0.0010
# Epoch 2/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6887 - loss: 0.6010 - val_accuracy: 0.7126 - val_loss: 0.5661 - learning_rate: 0.0010
# Epoch 3/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7281 - loss: 0.5482 - val_accuracy: 0.7253 - val_loss: 0.5436 - learning_rate: 0.0010
# Epoch 4/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7427 - loss: 0.5278 - val_accuracy: 0.7384 - val_loss: 0.5338 - learning_rate: 0.0010
# Epoch 5/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7540 - loss: 0.5108 - val_accuracy: 0.7321 - val_loss: 0.5294 - learning_rate: 0.0010
# Epoch 6/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7664 - loss: 0.4914 - val_accuracy: 0.7305 - val_loss: 0.5320 - learning_rate: 0.0010
# Epoch 7/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7707 - loss: 0.4845 - val_accuracy: 0.7342 - val_loss: 0.5291 - learning_rate: 0.0010
# Epoch 8/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7870 - loss: 0.4650 - val_accuracy: 0.7268 - val_loss: 0.5342 - learning_rate: 0.0010
# Epoch 9/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7970 - loss: 0.4508 - val_accuracy: 0.7321 - val_loss: 0.5379 - learning_rate: 0.0010
# Epoch 10/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8045 - loss: 0.4349 - val_accuracy: 0.7284 - val_loss: 0.5461 - learning_rate: 0.0010
# Epoch 11/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8110 - loss: 0.4215 - val_accuracy: 0.7279 - val_loss: 0.5501 - learning_rate: 0.0010
# Epoch 12/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8200 - loss: 0.4029 - val_accuracy: 0.7258 - val_loss: 0.5618 - learning_rate: 0.0010
# Epoch 13/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8376 - loss: 0.3724 - val_accuracy: 0.7216 - val_loss: 0.5703 - learning_rate: 5.0000e-04
# Epoch 14/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8481 - loss: 0.3563 - val_accuracy: 0.7189 - val_loss: 0.5823 - learning_rate: 5.0000e-04
# Epoch 15/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8464 - loss: 0.3427 - val_accuracy: 0.7242 - val_loss: 0.5957 - learning_rate: 5.0000e-04
# Epoch 16/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8587 - loss: 0.3331 - val_accuracy: 0.7237 - val_loss: 0.5862 - learning_rate: 5.0000e-04
# Epoch 17/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8596 - loss: 0.3245 - val_accuracy: 0.7247 - val_loss: 0.6022 - learning_rate: 5.0000e-04
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2025-04-08 09:29:46.996318: E tensorflow/core/framework/node_def_util.cc:676] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#
# Fold 4 Results:
# Accuracy: 0.7342
# Balanced Accuracy: 0.7342
# MCC: 0.4700
# Sensitivity: 0.7758
# Specificity: 0.6926
#
# Fold 5/5
# Epoch 1/50
# /home/ubuntu/data/miniconda3/envs/finetune-dephos/lib/python3.9/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5291 - loss: 0.6899 - val_accuracy: 0.6479 - val_loss: 0.6369 - learning_rate: 0.0010
# Epoch 2/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6481 - loss: 0.6227 - val_accuracy: 0.7163 - val_loss: 0.5623 - learning_rate: 0.0010
# Epoch 3/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7255 - loss: 0.5572 - val_accuracy: 0.7421 - val_loss: 0.5314 - learning_rate: 0.0010
# Epoch 4/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7396 - loss: 0.5346 - val_accuracy: 0.7426 - val_loss: 0.5207 - learning_rate: 0.0010
# Epoch 5/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7513 - loss: 0.5163 - val_accuracy: 0.7384 - val_loss: 0.5178 - learning_rate: 0.0010
# Epoch 6/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7627 - loss: 0.5073 - val_accuracy: 0.7368 - val_loss: 0.5136 - learning_rate: 0.0010
# Epoch 7/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7651 - loss: 0.4965 - val_accuracy: 0.7458 - val_loss: 0.5097 - learning_rate: 0.0010
# Epoch 8/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7767 - loss: 0.4758 - val_accuracy: 0.7468 - val_loss: 0.5085 - learning_rate: 0.0010
# Epoch 9/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7837 - loss: 0.4687 - val_accuracy: 0.7342 - val_loss: 0.5135 - learning_rate: 0.0010
# Epoch 10/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7935 - loss: 0.4614 - val_accuracy: 0.7289 - val_loss: 0.5191 - learning_rate: 0.0010
# Epoch 11/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8001 - loss: 0.4468 - val_accuracy: 0.7426 - val_loss: 0.5146 - learning_rate: 0.0010
# Epoch 12/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8033 - loss: 0.4316 - val_accuracy: 0.7463 - val_loss: 0.5139 - learning_rate: 0.0010
# Epoch 13/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8084 - loss: 0.4184 - val_accuracy: 0.7284 - val_loss: 0.5467 - learning_rate: 0.0010
# Epoch 14/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8220 - loss: 0.4005 - val_accuracy: 0.7326 - val_loss: 0.5442 - learning_rate: 5.0000e-04
# Epoch 15/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8169 - loss: 0.3984 - val_accuracy: 0.7358 - val_loss: 0.5366 - learning_rate: 5.0000e-04
# Epoch 16/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8319 - loss: 0.3819 - val_accuracy: 0.7247 - val_loss: 0.5583 - learning_rate: 5.0000e-04
# Epoch 17/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8264 - loss: 0.3809 - val_accuracy: 0.7363 - val_loss: 0.5365 - learning_rate: 5.0000e-04
# Epoch 18/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8376 - loss: 0.3689 - val_accuracy: 0.7353 - val_loss: 0.5437 - learning_rate: 5.0000e-04
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2025-04-08 09:30:10.711696: E tensorflow/core/framework/node_def_util.cc:676] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#
# Fold 5 Results:
# Accuracy: 0.7468
# Balanced Accuracy: 0.7468
# MCC: 0.4942
# Sensitivity: 0.7242
# Specificity: 0.7695
#
# Average Cross-validation Results:
# ACC: 0.7436 ± 0.0088
# BALANCED_ACC: 0.7436 ± 0.0088
# MCC: 0.4897 ± 0.0201
# SN: 0.7726 ± 0.0433
# SP: 0.7145 ± 0.0379
#
# Final Test Set Results:
# Accuracy: 0.7115
# Balanced Accuracy: 0.7422
# MCC: 0.2766
# Sensitivity: 0.7787
# Specificity: 0.7058
# Confusion Matrix:
# [[2097  874]
#  [  56  197]]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
